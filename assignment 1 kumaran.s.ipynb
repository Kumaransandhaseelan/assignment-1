# %%
#calculator

a=int(input("enter first number is:"))
b=int(input("enter second number is:"))

sum=a+b
sub=a-b
mul=a*b
div1=a%b 
div2=a/b

print("sum",sum)
print("sub",sub)
print("mul",mul)
print("div1",div1)
print("div2",div2)

print("assignment 1 is here please verify")
# Out:
# enter first number is:78
# enter second number is:95
# sum 173
# sub -17
# mul 7410
# div1 78
# div2 0.8210526315789474
# assignment 1 is here please verify
